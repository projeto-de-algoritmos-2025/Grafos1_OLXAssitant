# %%
import os

# Check if motos_data.json exists, remove it if it does, then run the olxSpider crawler
if os.path.exists('motos_data_raw.json'):
    os.remove('motos_data_raw.json')
os.system('scrapy runspider OlxSpider.py -o motos_data_raw.json')

# %%
import pandas as pd

df = pd.read_json('motos_data_raw.json')

df.shape[0]
# Out:
# 1482

# %%
df = df[df['status_financeiro'] != 'Financiado']
df['listId'] = df['listId'].astype(str)
df['listId'] = df['listId'].str[:-2]
df['quilometragem'] = df['quilometragem'].apply(lambda x: str(x) if isinstance(x, float) else x).astype(str).str[:-2]
df['ano'] = df['ano'].astype(str).str[:-2]

df.shape[0]
# Out:
# 1445

# %%
df.drop_duplicates(subset=['listId'], inplace=True)
df.shape[0]
# Out:
# 1264

# %%
df = df[df['listId'] != 'n']
df.reset_index(drop=True, inplace=True)
df
# Out:
#           listId                                              title  \
# 0     1367327410                            Kawasaki Versys GT 1000
# 1     1391008398                YAMAHA NMAX 160 2022 - pouco usada.
# 2     1396686759                                     Triumph Speed
# 3     1389556498                       Kawasaki ninja 650r ano 2012
# 4     1390374684  Factor 150 25/25 - Emplacamento + Capacete Grá...
# ...          ...                                                ...
# 1258  1395793361                                    CG 150 TITAN EX
# 1259  1375931553                        GS 1250 PREMIUM TROPHY 2023
# 1260  1387258622                                TIGER 1200 XCA 2020
# 1261  1396700528                                Z750 troco e vendo
# 1262  1368132661                            Vendo  Ducati XDiavel S
#
#           price estado                                                url  \
# 0     R$ 62.000     DF  https://df.olx.com.br/distrito-federal-e-regia...
# 1     R$ 18.000     DF  https://df.olx.com.br/distrito-federal-e-regia...
# 2     R$ 55.000     DF  https://df.olx.com.br/distrito-federal-e-regia...
# 3     R$ 23.990     DF  https://df.olx.com.br/distrito-federal-e-regia...
# 4     R$ 18.990     DF  https://df.olx.com.br/distrito-federal-e-regia...
# ...         ...    ...                                                ...
# 1258  R$ 10.500     SP  https://sp.olx.com.br/regiao-de-ribeirao-preto...
# 1259  R$ 95.000     SP  https://sp.olx.com.br/regiao-de-sorocaba/autos...
# 1260  R$ 68.900     SP  https://sp.olx.com.br/regiao-de-ribeirao-preto...
# 1261  R$ 30.000     SP  https://sp.olx.com.br/vale-do-paraiba-e-litora...
# 1262  R$ 75.000     SP  https://sp.olx.com.br/sao-paulo-e-regiao/autos...
#
#           cilindrada     marca                      modelo     ano  \
# 0               1000  KAWASAKI  KAWASAKI 1000 GRAND TOURER  2021.0
# 1                160    YAMAHA                  YAMAHA 160  2022.0
# 2     Acima de 1.000   TRIUMPH        TRIUMPH TRIPLE 1050I  2014.0
# 3                600  KAWASAKI         KAWASAKI 650R 649CC  2012.0
# 4                150    YAMAHA               YAMAHA 150 ED  2025.0
# ...              ...       ...                         ...     ...
# 1258             150     HONDA      HONDA 150 TITAN-ES MIX  2012.0
# 1259  Acima de 1.000       BMW    BMW 1250 GS PEMIUM TOPHY  2023.0
# 1260  Acima de 1.000   TRIUMPH            TRIUMPH 1200 XCA  2020.0
# 1261             750  KAWASAKI                KAWASAKI 750  2010.0
# 1262  Acima de 1.000    DUCATI               DUCATI S 1262  2018.0
#
#      quilometragem status_financeiro  \
# 0            64000           Quitado
# 1            15000           Quitado
# 2             8120           Quitado
# 3            46800           Quitado
# 4                0      Desconhecido
# ...            ...               ...
# 1258         80000           Quitado
# 1259         16790           Quitado
# 1260         17800      Desconhecido
# 1261         46000           Quitado
# 1262          3700      Desconhecido
#
#                                               locations  \
# 0     Brasília, Setor Habitacional Jardim Botânico -...
# 1                         Brasília, Sobradinho - DDD 61
# 2                     Brasília, Setor Sudoeste - DDD 61
# 3     Brasília, Setor Habitacional Arniqueira (Águas...
# 4                          Brasília, Asa Norte - DDD 61
# ...                                                 ...
# 1258   Ribeirão Preto, Parque dos Bandeirantes - DDD 16
# 1259                Sorocaba, Jardim Vera Cruz - DDD 15
# 1260                     Santa Rosa de Viterbo - DDD 16
# 1261          Jacareí, Residencial Santa Paula - DDD 12
# 1262                     São Paulo, Vila Maria - DDD 11
#
#                                                 imagens
# 0     [{'original': 'https://img.olx.com.br/images/2...
# 1     [{'original': 'https://img.olx.com.br/images/8...
# 2     [{'original': 'https://img.olx.com.br/images/6...
# 3     [{'original': 'https://img.olx.com.br/images/6...
# 4     [{'original': 'https://img.olx.com.br/images/2...
# ...                                                 ...
# 1258  [{'original': 'https://img.olx.com.br/images/9...
# 1259  [{'original': 'https://img.olx.com.br/images/7...
# 1260  [{'original': 'https://img.olx.com.br/images/7...
# 1261  [{'original': 'https://img.olx.com.br/images/4...
# 1262  [{'original': 'https://img.olx.com.br/images/7...
#
# [1263 rows x 13 columns]

# %%
df.to_json('motos_data.json', orient='records')
