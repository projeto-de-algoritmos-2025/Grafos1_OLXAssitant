# %%
import pandas as pd

df = pd.read_json('df_motos.json')

df = df[df['status_financeiro'] == 'Quitado']
df['listId'] = df['listId'].astype(str).str[:-2]
df
# Out:
#         listId                                              title      price  \
# 1   1396476875    VENDE-SE HARLEY DAVIDSON VROD (edição especial)  R$ 53.900
# 2   1392339539                           Moto elétrica Voltz evs   R$ 15.000
# 3   1396474768  Moto pra Ganhar DINHEIRO! PCX 150 DLX 2021 - C...  R$ 16.470
# 6   1396495087                                          CBR1000RR  R$ 33.000
# 9   1396489180                        Honda Shadow 600cc ano 2001  R$ 21.500
# 10  1357598230  HONDA CB650R 22/22 14MILKM IPVA 2025 PAGO/REVI...  R$ 50.500
# 13  1390120382                 Triumph Tiger 900 GT Pró - 2021/21  R$ 56.990
# 16  1396485965                           Vendo linda biz em dias    R$ 4.500
# 17  1395505317           Sahara 300 2025 700 km Zero sem detalhes  R$ 33.000
# 21  1372364145                              Nova Yamaha Factor DX       None
# 22  1396480160                     Yamaha/FAZER 250  R$:18.500,00  R$ 18.500
# ...
